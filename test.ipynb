# %%
import pandas as pd

# %%
df = pd.read_csv("visa_number_in_japan.csv")
df.
# Out:
# Index(['Year', 'Regional code', 'Country', 'Number of issued',
#        'Number of issued_numerical', 'Travel certificate', 'Diplomacy',
#        'Public use', 'Passing', 'Short -term stay', 'Staying in medical care',
#        'Advanced profession', 'Employment', 'Employment_Professor',
#        'Employment_Art', 'Employment_religion', 'Employment_Report',
#        'Employment_Management / Management', 'Employment_Law accounting',
#        'Employment_Medical care', 'Employment_Research',
#        'Employment_Education', 'Employment_Country', 'Employment_Technology',
#        'Employment_Humanities International',
#        'Employment_C corporate rotation', 'Employment_show',
#        'Employment_Skills', 'Employment_Steng (new)',
#        'Employment_Nursing care', 'Ordinary', 'General_Cultural activity',
#        'General_Studying abroad', 'General_Arademy', 'General_Training',
#        'General_Family stay', 'General_Stifying 1 I', 'General_Steng 1',
# ...
